# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns

df = pd.read_csv('../data/bike.csv') #자전거 사용 데이터 프레임
df
# Out:
#      month  day quarter day_of_week  workingday  holiday  temperature  \
# 0        1    1      1Q         SUN           0        0         21.4
# 1        1    2      1Q         MON           0        1         15.0
# 2        1    3      1Q         TUE           1        0          7.6
# 3        1    4      1Q         WED           1        0          0.4
# 4        1    5      1Q         THU           1        0         14.2
# ..     ...  ...     ...         ...         ...      ...          ...
# 361     12   27      4Q         THU           1        0         10.0
# 362     12   28      4Q         FRI           1        0         14.0
# 363     12   29      4Q         SAT           0        0         14.9
# 364     12   30      4Q         SUN           0        0         16.5
# 365     12   31      4Q         MON           1        0          3.5
#
#      humidity  windspeed  registered  casual  total
# 0          72         12        1608     686   2294
# ...

# %%
#스트리플랏, 스케터플랏

# %%
sns.stripplot(data=df, x='month', y='total', hue='workingday')
# Out:
# <Axes: xlabel='month', ylabel='total'>

# %%
sns.stripplot(data=df, x='month', y='total', hue='workingday', jitter=True)
# Out:
# <Axes: xlabel='month', ylabel='total'>

# %%
sns.swarmplot(data=df, x='month', y='total', hue='workingday')
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/seaborn/categorical.py:3399: UserWarning: 6.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.12/site-packages/seaborn/categorical.py:3399: UserWarning: 6.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.12/site-packages/seaborn/categorical.py:3399: UserWarning: 10.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='month', ylabel='total'>

# %%
sns.violinplot(data=df, x='month', y='total', palette="pink")
# Out:
# /var/folders/j3/1698k0557xj2ck4v4pfz6v640000gn/T/ipykernel_56016/2353912019.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x='month', y='total', palette="pink")
# <Axes: xlabel='month', ylabel='total'>

# %%
sns.boxplot(data=df, x='day_of_week', y='registered')
# Out:
# <Axes: xlabel='day_of_week', ylabel='registered'>

# %%
sns.boxplot(data=df, x='day_of_week', y='registered'
            , order=['MON, 'TUE', "WED', "THU", "FRI", 'SAT, 'SUN'])
# Out:
#   Cell In[10], line 2
#     , order=['MON, 'TUE', "WED', "THU", "FRI", 'SAT, 'SUN'])
#                                                          ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
sns.boxplot(data=df, x='day_of_week', y='registered'
            , order=['MON', 'TUE', 'WED', 'THU', "FRI", 'SAT, 'SUN'])
# Out:
#   Cell In[11], line 2
#     , order=['MON', 'TUE', 'WED', 'THU', "FRI", 'SAT, 'SUN'])
#                                                           ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
sns.boxplot(data=df, x='day_of_week', y='registered'
            , order=['MON', 'TUE', 'WED', 'THU', "FRI", 'SAT', 'SUN'])
# Out:
# <Axes: xlabel='day_of_week', ylabel='registered'>

# %%
sns.boxplot(data=df, x='day_of_week', y='registered'
            , order=['MON', 'TUE', 'WED', 'THU', "FRI", 'SAT', 'SUN']
            ,palette="pink")
# Out:
# /var/folders/j3/1698k0557xj2ck4v4pfz6v640000gn/T/ipykernel_56016/3403435513.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='day_of_week', y='registered'
# <Axes: xlabel='day_of_week', ylabel='registered'>

# %%
sns.violinplot(data=df, x='day_of_week', y='registered'
            , order=['MON', 'TUE', 'WED', 'THU', "FRI", 'SAT', 'SUN']
            ,palette="pink")
# Out:
# /var/folders/j3/1698k0557xj2ck4v4pfz6v640000gn/T/ipykernel_56016/3687184712.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x='day_of_week', y='registered'
# <Axes: xlabel='day_of_week', ylabel='registered'>

# %%
sns.histplot(data=df, x='registered', y='day_of_week', multiple='stack', bins=10
            ,palette="pink")
# Out:
# /var/folders/j3/1698k0557xj2ck4v4pfz6v640000gn/T/ipykernel_56016/2468846837.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=df, x='registered', y='day_of_week', multiple='stack', bins=10
# <Axes: xlabel='registered', ylabel='day_of_week'>

# %%
sns.set_theme(rc={'figure.figsize':(6,6)}, style='white')
sns.scatterplot(data=df, x='temperature', y='total')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 3
#       1 sns.set_theme(rc={'figure.figsize':(6,6)}, style='white')
#       2 sns.scatterplot(data=df, x='temperature', y='total')
# ----> 3 plt.show()
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/_api/__init__.py:217, in caching_module_getattr.<locals>.__getattr__(name)
#     215 if name in props:
#     216     return props[name].__get__(instance)
# --> 217 raise AttributeError(
#     218     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'show'

# %%
sns.set_theme(rc={'figure.figsize' : (12, 6)})
sns.barplot(data=df, x='month', y='total', errorbar = None, hue='workingday')
plt.show()
# Out:
# ---------------------------------------------------------------------------
#
# AttributeError                            Traceback (most recent call last)
#
# Cell In[15], line 3
#
#       1 sns.set_theme(rc={'figure.figsize' : (12, 6)})
#
#       2 sns.barplot(data=df, x='month', y='total', errorbar = None, hue='workingday')
#
# ----> 3 plt.show()
#
#
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/_api/__init__.py:217, in caching_module_getattr.<locals>.__getattr__(name)
#
#     215 if name in props:
#
#     216     return props[name].__get__(instance)
#
# --> 217 raise AttributeError(
#
#     218     f"module {cls.__module__!r} has no attribute {name!r}")
#
#
#
# AttributeError: module 'matplotlib' has no attribute 'show'

# %%
sns.set_theme(rc={'figure.figsize':(6,6)}, style='white')
sns.scatterplot(data=df, x='temperature', y='total')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 3
#       1 sns.set_theme(rc={'figure.figsize':(6,6)}, style='white')
#       2 sns.scatterplot(data=df, x='temperature', y='total')
# ----> 3 plt.show()
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/_api/__init__.py:217, in caching_module_getattr.<locals>.__getattr__(name)
#     215 if name in props:
#     216     return props[name].__get__(instance)
# --> 217 raise AttributeError(
#     218     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'show'

# %%
sns.regplot(data=df, x='temperature', y='total')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 2
#       1 sns.regplot(data=df, x='temperature', y='total')
# ----> 2 plt.show()
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/_api/__init__.py:217, in caching_module_getattr.<locals>.__getattr__(name)
#     215 if name in props:
#     216     return props[name].__get__(instance)
# --> 217 raise AttributeError(
#     218     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'show'

# %%
sns.regplot(data=df, x='humidity', y='total')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 2
#       1 sns.regplot(data=df, x='humidity', y='total')
# ----> 2 plt.show()
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/_api/__init__.py:217, in caching_module_getattr.<locals>.__getattr__(name)
#     215 if name in props:
#     216     return props[name].__get__(instance)
# --> 217 raise AttributeError(
#     218     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'show'

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
df.corr(numeric_only=True) #correlation의 약자
# Out:
#                 month       day  workingday   holiday  temperature  humidity  \
# month        1.000000  0.006443   -0.007513  0.006258     0.128435  0.191763
# day          0.006443  1.000000    0.022520 -0.031464     0.006938  0.092935
# workingday  -0.007513  0.022520    1.000000 -0.258418     0.029387  0.043649
# holiday      0.006258 -0.031464   -0.258418  1.000000    -0.019713 -0.023121
# temperature  0.128435  0.006938    0.029387 -0.019713     1.000000  0.087400
# humidity     0.191763  0.092935    0.043649 -0.023121     0.087400  1.000000
# windspeed   -0.043407  0.024777   -0.072115  0.057260    -0.114972 -0.221569
# registered   0.281855 -0.055827    0.437003 -0.164190     0.554088 -0.049545
# casual       0.099117 -0.019697   -0.539919  0.029720     0.477538 -0.066836
# total        0.266502 -0.052814    0.118884 -0.118134     0.643860 -0.067814
#
#              windspeed  registered    casual     total
# month        -0.043407    0.281855  0.099117  0.266502
# ...

# %%
#수치형과 수치형 사이의 관계를 보여줌
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
#독립적인 변수 두개 사이에서 상관계수 값이 높아야 의미가 있는 인사이트를 얻을 수 있음.
#의존변수 (등록자가 많으면 토탈이 높아진다 등)의 관계성이 높아도 의미 없음. 의미있는 인사이트를 얻을 수 없음

# %%
sns.heatmap(data=df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
df.corr(numeric_only=True)[['total']]
# Out:
#                 total
# month        0.266502
# day         -0.052814
# workingday   0.118884
# holiday     -0.118134
# temperature  0.643860
# humidity    -0.067814
# windspeed   -0.189995
# registered   0.912994
# casual       0.643305
# total        1.000000

# %%
df.corr(numeric_only=True)[['total']].drop('total', axis=0)
# Out:
#                 total
# month        0.266502
# day         -0.052814
# workingday   0.118884
# holiday     -0.118134
# temperature  0.643860
# humidity    -0.067814
# windspeed   -0.189995
# registered   0.912994
# casual       0.643305

# %%
sns.heatmap(df.corr(numeric_only=True)[['total']].drop('total', axis=0))
# Out:
# <Axes: >

# %%
sns.heatmap(df.corr(numeric_only=True)[['total']].drop('total', axis=0), annot=True)
# Out:
# <Axes: >
