# %%
import pandas as pd
import matplotlib.pyplot as plt

starbucks_df = pd.read_csv('../data/starbucks.csv')

starbucks_df
# Out:
#                        category  \
# 0       Classic Espresso Drinks
# 1     Signature Espresso Drinks
# 2       Classic Espresso Drinks
# 3    Frappuccino® Blended Crème
# 4       Classic Espresso Drinks
# ..                          ...
# 214     Classic Espresso Drinks
# 215                      Coffee
# 216   Signature Espresso Drinks
# 217   Signature Espresso Drinks
# 218            Tazo® Tea Drinks
#
#                                           beverage              option  \
# 0                       Skinny Latte (Any Flavour)  Grande Nonfat Milk
# 1                                Caramel Macchiato  Grande Nonfat Milk
# 2                       Skinny Latte (Any Flavour)   Short Nonfat Milk
# 3     Strawberries & Crème (Without Whipped Cream)  Grande Nonfat Milk
# 4                                      Caffè Latte  Grande Nonfat Milk
# ..                                             ...                 ...
# 214                                     Cappuccino    Tall Nonfat Milk
# ...

# %%
starbucks_df['calories'].plot(kind='box')
plt.show()

# %%
import pandas as pd

car_df = pd.read_csv('../data/car.csv')
car_df
# 여기에 코드를 작성하세요.
# Out:
#         manufacturer   category fuel_type  engine_volume  mileage  price
# 0            HYUNDAI       Jeep    Petrol            2.0    36800  36065
# 1             TOYOTA      Sedan    Petrol            2.5   107000  15053
# 2             NISSAN       Jeep    Petrol            1.6   108222   7527
# 3                BMW       Jeep    Diesel            3.0    18000  15681
# 4      MERCEDES-BENZ  Hatchback    Petrol            1.7   160000  13485
# ...              ...        ...       ...            ...      ...    ...
# 12014         TOYOTA  Hatchback    Hybrid            1.5   181474  14831
# 12015      CHEVROLET       Jeep    Diesel            2.0    70922  41055
# 12016        HYUNDAI       Jeep    Diesel            2.0   273371  27858
# 12017          LEXUS       Jeep       LPG            4.7   170000  34497
# 12018  MERCEDES-BENZ      Coupe    Petrol            2.3   157000   7213
#
# [12019 rows x 6 columns]

# %%
hyundai_df = car_df[car_df['manufacturer'] == 'HYUNDAI']
hyundai_df['price'].plot(kind='hist', bins= 10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
car_df['manufacturer'].unique()
# Out:
# array(['HYUNDAI', 'TOYOTA', 'NISSAN', 'BMW', 'MERCEDES-BENZ',
#        'VOLKSWAGEN', 'CHEVROLET', 'FORD', 'HONDA', 'LEXUS', 'AUDI'],
#       dtype=object)

# %%
car_df['manufacturer'].tolist()
# Out:
# ['HYUNDAI',
#  'TOYOTA',
#  'NISSAN',
#  'BMW',
#  'MERCEDES-BENZ',
#  'VOLKSWAGEN',
#  'HYUNDAI',
#  'CHEVROLET',
#  'TOYOTA',
#  'FORD',
#  'HYUNDAI',
#  'MERCEDES-BENZ',
#  'TOYOTA',
#  'FORD',
#  'HYUNDAI',
#  'BMW',
#  'MERCEDES-BENZ',
#  'HYUNDAI',
#  'FORD',
#  'HYUNDAI',
#  'HYUNDAI',
#  'VOLKSWAGEN',
#  'HYUNDAI',
#  'VOLKSWAGEN',
#  'TOYOTA',
#  'HYUNDAI',
#  'CHEVROLET',
#  'TOYOTA',
#  'HYUNDAI',
#  'BMW',
#  'HONDA',
#  'HYUNDAI',
#  'HYUNDAI',
#  'HYUNDAI',
#  'HONDA',
#  'MERCEDES-BENZ',
#  'BMW',
#  'TOYOTA',
#  'TOYOTA',
#  'HYUNDAI',
#  'TOYOTA',
#  'MERCEDES-BENZ',
#  'HONDA',
#  'TOYOTA',
#  'HYUNDAI',
#  'LEXUS',
#  'TOYOTA',
#  'TOYOTA',
#  'HYUNDAI',
#  'BMW',
#  'HYUNDAI',
#  'LEXUS',
#  'MERCEDES-BENZ',
#  'MERCEDES-BENZ',
#  'HONDA',
#  'TOYOTA',
#  'BMW',
#  'AUDI',
#  'HYUNDAI',
#  'LEXUS',
#  'BMW',
#  'FORD',
#  'MERCEDES-BENZ',
#  'MERCEDES-BENZ',
#  'HYUNDAI',
#  'TOYOTA',
#  'TOYOTA',
#  'TOYOTA',
#  'TOYOTA',
#  'TOYOTA',
#  'TOYOTA',
# ...

# %%
#HYUNDAI', 'TOYOTA', 'NISSAN', 'BMW', 'MERCEDES-BENZ',
#'VOLKSWAGEN', 'CHEVROLET', 'FORD', 'HONDA', 'LEXUS', 'AUDI'


toyota_df = car_df[car_df['manufacturer'] == 'TOYOTA']
toyota_df['price'].plot(kind='hist', bins = 10)
plt.show()

# %%
#HYUNDAI', 'TOYOTA', 'NISSAN', 'BMW', 'MERCEDES-BENZ',
#'VOLKSWAGEN', 'CHEVROLET', 'FORD', 'HONDA', 'LEXUS', 'AUDI'


nissan_df = car_df[car_df['manufacturer'] == 'NISSAN']
nissan_df['price'].plot(kind='hist', bins = 10)
plt.show()

# %%
#HYUNDAI', 'TOYOTA', 'NISSAN', 'BMW', 'MERCEDES-BENZ',
#'VOLKSWAGEN', 'CHEVROLET', 'FORD', 'HONDA', 'LEXUS', 'AUDI'


BMW_df = car_df[car_df['manufacturer'] == 'BMW']
BMW_df['price'].plot(kind='hist', bins = 10)
plt.show()

# %%
#HYUNDAI', 'TOYOTA', 'NISSAN', 'BMW', 'MERCEDES-BENZ',
#'VOLKSWAGEN', 'CHEVROLET', 'FORD', 'HONDA', 'LEXUS', 'AUDI'


MERCEDESBENZ_df = car_df[car_df['manufacturer'] == 'MERCEDES-BENZ']
MERCEDESBENZ_df['price'].plot(kind='hist', bins = 10)
plt.show()

# %%
#HYUNDAI', 'TOYOTA', 'NISSAN', 'BMW', 'MERCEDES-BENZ',
#'VOLKSWAGEN', 'CHEVROLET', 'FORD', 'HONDA', 'LEXUS', 'AUDI'


VOLKSWAGEN_df = car_df[car_df['manufacturer'] == 'VOLKSWAGEN']
VOLKSWAGEN_df['price'].plot(kind='hist', bins = 10)
plt.show()

# %%
audi_df = car_df[car_df['manufacturer'] == 'AUDI']
audi_df['price'].plot(kind='box')
plt.show()

# %%
q1 = car_df['mileage'].quantile(0.25)
q3 = car_df['mileage'].quantile(0.75)

iqr = q3 - q1

q1, q3, iqr
# Out:
# (70000.0, 177932.0, 107932.0)

# %%
lower_whisker = q1 - 1.5 * iqr
upper_whisker = q3 + 1.5 * iqr

lower_whisker, upper_whisker
# Out:
# (-91898.0, 339830.0)
